# %%
# %matplotlib notebook
import numpy as np
from ncempy.io import dm
import matplotlib.pyplot as plt
import hyperspy.api as hp

# %%
s = hp.load('Data/Diffraction SI.dm4')
#im0 = dm.dmReader('Data/Diffraction SI.dm4')

# %%
im01 = im0['data'].mean(0).mean(0)
im01
# Out:
# array([[0.52632952, 0.38175054, 0.34688246, ..., 0.38283502, 0.31228894,
#         0.37583395],
#        [0.50625978, 0.47025231, 0.37365126, ..., 0.40357741, 0.46602422,
#         0.42625539],
#        [0.62305411, 0.55865799, 0.48717843, ..., 0.48005381, 0.55784806,
#         0.49991763],
#        ...,
#        [0.41878758, 0.42228811, 0.3947643 , ..., 0.51932845, 0.46099992,
#         0.43797875],
#        [0.55022925, 0.48209922, 0.62174999, ..., 0.58814485, 0.55024298,
#         0.44127337],
#        [0.85522884, 1.07252286, 1.08765066, ..., 1.14194328, 0.77750323,
#         1.12750185]])

# %%
plt.imshow(im01) #show the single image from the data file

# %%
s.plot(navigator ='slider')
# Out:
# VBox(children=(HBox(children=(Label(value='Unnamed 0th axis', layout=Layout(width='15%')), IntSlider(value=114…
# <img src="data:image/png;base64,..." width="640">

# %%
s
# Out:
# <Signal2D, title: Diffraction SI, dimensions: (342, 213|256, 256)>

# %%
import pixstem.api as ps
#s = ps.load('Data/Diffraction SI.dm4')
s = ps.DPCSignal2D(s)

# %%
s
# Out:
# <DPCSignal2D, title: , dimensions: (342, 213|256, 256)>

# %%
s.plot(navigator ='slider')
# Out:
# VBox(children=(HBox(children=(Label(value='Unnamed 0th axis', layout=Layout(width='15%')), IntSlider(value=0, …
# <img src="data:image/png;base64,..." width="640">
