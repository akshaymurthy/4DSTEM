# %%
# %matplotlib notebook
import numpy as np
from ncempy.io import dm
import matplotlib.pyplot as plt
import hyperspy.api as hp
# Out:
# WARNING:hyperspy_gui_traitsui:The nbAgg matplotlib backend is not compatible with the traitsui GUI elements. For more information, read http://hyperspy.readthedocs.io/en/stable/user_guide/getting_started.html#possible-warnings-when-importing-hyperspy.
# WARNING:hyperspy_gui_traitsui:The traitsui GUI elements are not available.

# %%
s = hp.load('Diffraction SI.dm4')
im0 = dm.dmReader('Diffraction SI.dm4')

# %%
im01 = im0['data']
type(im01)
# Out:
# numpy.ndarray

# %%
plt.imshow(im01) #show the single image from the data file
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s.plot(navigator ='slider')
# Out:
# ...
# <img src="data:image/png;base64,..." width="640">

# %%
s
# Out:
# <Signal2D, title: Diffraction SI, dimensions: (342, 213|256, 256)>

# %%
import pixstem.api as ps
#s = ps.load('Data/Diffraction SI.dm4')
s = ps.DPCSignal2D(s)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-4586db8490cf> in <module>
# ----> 1 import pixstem.api as ps
#       2 #s = ps.load('Data/Diffraction SI.dm4')
#       3 s = ps.DPCSignal2D(s)
#
# ModuleNotFoundError: No module named 'pixstem'

# %%
s
# Out:
# <Signal2D, title: Diffraction SI, dimensions: (342, 213|256, 256)>

# %%
s.plot(navigator ='slider')
# Out:
# ...
# <img src="data:image/png;base64,..." width="640">
